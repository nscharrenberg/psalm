# %%
from pathlib import Path
from psalm.evaluators.control_analyzer import ControlValidationAnalyzer

# Configure paths
results_dir = Path("../../../../results/control")  # Directory with JSON files
output_dir = Path("publication/rq1")

# Run analysis
analyzer = ControlValidationAnalyzer(
        results_dir=results_dir,
        output_dir=output_dir
)

analyzer.run_full_validation()
# Out:
# ...
# STARTING PSALM EVALUATOR VALIDATION ANALYSIS
# ...
#
# 1. Loading control experiment results...
#   Loading character_similarity.json -> Character Similarity
#   Loading narrative_voice.json -> Narrative Voice
#   Loading parody_satire.json -> Parody Satire
#   Loading pastiche.json -> Pastiche
#   Loading plot_structure_similarity.json -> Plot Structure Similarity
#   Loading quotation_citation.json -> Quotation Citation
#   Loading scenes_a_faire.json -> Scenes à Faire
#   Loading scene_sequence_similarity.json -> Scene Sequence Similarity
#   Loading world_building_similarity.json -> World Building Similarity
#   Loading writing_style.json -> Writing Style
#
# ✓ Loaded 250 test runs
#   Evaluators: 10
#   Test Cases: 50
#   Total Runs: 250
#
# 2. Computing validation metrics...
#    ✓ Validation metrics computed
#
# 3. Generating visualizations...
# ✓ Saved publication\rq1\validation_heatmap.png
# ✓ Saved publication\rq1\absolute_error_by_evaluator.png
# ...
