# %%
import polars as pl
file_name = "results_EN_NPO_e20-ue3-subset"
file_path = f"../../../results/evaluation/{file_name}.parquet"
save_path = f"../../../results/evaluation/{file_name}.json"
csv_path = f"../../../results/evaluation/final/{file_name}.csv"
df = pl.read_parquet(file_path)

# df.write_json(save_path)
df.write_csv(csv_path)
