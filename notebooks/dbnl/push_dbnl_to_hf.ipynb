# %%
import polars as pl
import nest_asyncio
nest_asyncio.apply()

author_name = "*"
genre_name = "*"
DATASET_PATH = f"data/qa/selected_books_v2/{genre_name}/Nederlands/qa_{author_name}.parquet"

df_nl = pl.read_parquet(DATASET_PATH)

# %%
# DATASET_PATH = f"data/qa/selected_books/{genre_name}/english/qa_{author_name}.parquet"
#
# df = pl.read_parquet(DATASET_PATH)

# %%
# genres = []
# ti_ids = []
# for en_row in df.iter_rows(named=True):
#     ti_id = en_row["ti_id"]
#     found = False
#     for nl_row in df_nl.iter_rows(named=True):
#         if nl_row["ti_id"] == ti_id:
#             ti_ids.append(ti_id)
#             genres.append(nl_row["genre"])
#             found = True
#             break
#
#     if not found:
#         print(f"ti_id {ti_id} not found in nl")
#
#
# if len(ti_ids) != len(genres):
#     raise Exception("ti_ids and genres are not the same length")
#
# print(f"DF: {len(df)}, genres: {len(genres)}")
#
#
# # Add genres to df
# df = df.with_columns(pl.Series(name="genre", values=genres)).select(pl.col('ti_id'), pl.col('author'), pl.col('genre'), pl.col('question'), pl.col('answer'))
# Out:
# DF: 19, genres: 19

# %%
# df.write_parquet(DATASET_PATH)

# %%
from datasets import Dataset, Split

HF_PATH = "nscharrenberg/DBNL-public"
SUBSET = "qa_nl"
SPLIT = Split.TRAIN

ds = Dataset.from_polars(df_nl, split=SPLIT)

# %%
ds.push_to_hub(HF_PATH, SUBSET)
# Out:
# ...
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md: 0.00B [00:00, ?B/s]
# C:\Users\NoahScharrenberg\Desktop\projects\psalm\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\NoahScharrenberg\.cache\huggingface\hub\datasets--nscharrenberg--DBNL-public. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...
