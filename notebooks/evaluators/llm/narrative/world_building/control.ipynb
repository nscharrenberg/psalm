# %%
import nest_asyncio
from psalm.configs.experiments import ControlExperimentConfig

nest_asyncio.apply()

config = ControlExperimentConfig()
config.model.model_name = "gpt-5-nano"
config.dataset_path = "control.json"
config.debug = True

# %%
from psalm.evaluators.llm.narrative import WorldBuildingSimilarityEvaluator
from psalm.experiments import ControlExperiment

experiment = ControlExperiment(config, WorldBuildingSimilarityEvaluator)
results, errors = experiment.execute(use_async=True)
# Out:
# ─────────────────────────────────────────── Control Experiment (Async) ────────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Output()
# Output()
# Output()
# Output()
# Output()
# **************************************************
# WorldBuilding Similarity [DAG] Verbose Logs
# **************************************************
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ______________________
# | TaskNode | Level == 0 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. Geographic specificity (detailed locations with unique features, particular spatial layouts,
#                distinctive topographical characteristics, creative geographic elaborations)
#             2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns,
#                distinctive natural phenomena, creative environmental elaborations)
#
#             CRITICAL DISTINCTION:
#             - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city,"
#               "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"
#             - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular
#               spatial configurations, specific topographical relationships, unique ecological characteristics,
#               creative elaborations
#
#             Examples of SPECIFIC elements:
#             - "Capital city built in spiral pattern ascending specific mountain with unique terraced architecture;
#               city divided into 7 distinct districts with particular spatial relationships (outer commercial ring
#               connects to inner administrative zone via specific network of bridges crossing artificial canals at
#               detailed elevations); mountain has particular geological feature (crystalline formations at specific
#               locations)"
#             - "Desert characterized by specific phenomenon: sand turns crystalline under particular conditions
#               (when exposed to specific temperature/moisture combination during seasonal event); unique ecosystem
#               where specific flora (detailed plants with particular adaptations) survive through creative
# mechanism;
#               climate follows detailed pattern (temperature fluctuations, wind patterns, precipitation cycles with
#               specific timings and causes)"
#
#             Provide a structured comparison of geographic and spatial design between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             IGNORE generic labels ("kingdom," "city," "desert," "forest"). FOCUS ONLY on SPECIFIC, DETAILED
#             geographic and environmental elaborations.
#
#
# Geographic & Spatial Design Analysis:
# Structured comparison of geographic and spatial design between EXPECTED OUTPUT and ACTUAL OUTPUT
#
# 1) Texts considered
# - EXPECTED OUTPUT: Glass Archipelago with floating islands on a salt-brine sea; land held together by glass roofs;
# constellations refracted into lantern-lit lanes; currents chart routes with wind-sung sigils; gravity shifts at
# dusk; hillside harbors; memory wells; memory coins; roofs collect rain to rooftop gardens; inscriptions rearrange
# with the flood; world described as delicate and luminous.
# - ACTUAL OUTPUT: Glass Archipelago with floating islands on a salt-brine sea; land stays beneath glass domes that
# bend starlight into market lanes; currents chart routes with wind-sung sigils; gravity shifts at dusk; slopes
# carved into cliffs; memory wells; tiny shells that record promises; roofs collect rain to feed rooftop gardens;
# inscriptions rearrange with each flood; world described as delicate and luminous.
#
# 2) Geographic specificity
# - EXPECTED OUTPUT – Geographic specificity (high detail):
#   • Islands float on a salt-brine sea that sings when storms approach.
#   • Land is held together by glass roofs that refract constellations into lantern-lit lanes.
#   • Currents chart routes with wind-sung sigils.
#   • Gravity shifts at dusk, allowing boats to glide uphill along hillside harbors.
#   • Human settlements integrate with weather-driven infrastructure (roofs funnel rain to rooftop gardens).
#   • Memory-based economy and inscriptions that respond to environmental change (floods).
#   • Memory wells and memory coins reinforce a unique cultural-geographic system.
# - ACTUAL OUTPUT – Geographic specificity (high similarity with minor rewording):
#   • Islands float on a salt-brine sea that whispers/sings when storms approach (similar meteorological imagery).
#   • Land stays beneath glass domes that bend starlight into market lanes (similar function but different wording).
#   • Currents chart routes with wind-sung sigils.
#   • Gravity shifts at dusk, letting boats glide uphill along slopes carved into cliffs (topography specified as
# cliffs vs hillside harbors).
#   • Memory wells and shells that record promises (regional variation: shells instead of memory coins; wording
# changes but function similar).
#   • Weather-driven architecture: roofs collect rain to feed rooftop gardens (similar, minor wording change).
#   • Inscriptions rearrange with each flood (variation from “the flood” to “each flood”).
#
# Assessment of geographic specificity: Both texts provide highly specific, creative geographic and spatial
# elaborations with unique topographical features (hillside harbors vs carved slopes into cliffs) and distinctive
# light/traffic networks mediated by glass and celestial phenomena. The Actual Output preserves the same spatial
# architecture and cultural-geographic system with minor linguistic variations.
#
# 3) Environmental elaboration
# - EXPECTED OUTPUT – Environmental detail (moderate/elaborated):
#   • The sea’s singing as storms approach signals an environmental ambiance.
#   • Glass roofs refract constellations into navigational/light paths, integrating climate perception with urban
# design.
#   • Roofs collect rain into channels nourishing rooftop gardens, suggesting a micro-ecology atop structures.
#   • Species/ecosystem detail is not deeply fleshed out; emphasis is on environmental phenomena (weather-sound,
# memory wells) shaping human adaptation.
# - ACTUAL OUTPUT – Environmental detail (very similar, with slight wording changes):
#   • The sea whispers/sings with approaching storms (same environmental leitmotif).
#   • Glass domes bend starlight into market lanes, maintaining a strong light/climate-influenced urban morphology.
#   • Rain channels nourish rooftop gardens, indicating a parallel micro-ecology on built forms.
#   • Inscriptions rearrange with floods, implying dynamic environmental interaction, but explicit ecological
# descriptions remain minimal.
#
# Assessment of environmental elaboration: Both texts emphasize environmental phenomena (storm-sung seas,
# light-refracting glass architecture, rain-driven rooftop ecosystems) as drivers of spatial design. Detailed,
# species-level ecosystems or climate patterns are not the focus; the environmental elaboration is thematic and
# design-oriented in both.
#
# 4) Overall similarity categorization
# - Based on geographic specificity and environmental elaboration, the two texts are:
#   Very similar worldbuilding with only minor differences
#   (core concepts, spatial configurations, topographical cues, and ecological-meets-architectural logic are
# preserved; differences are stylistic or terminological and do not overturn the system).
#
# 5) Key points of alignment and minor differences (illustrative examples)
# - Alignment:
#   • Shared core setting: Glass Archipelago with floating islands on a salt-brine sea.
#   • Common architectural-material motif: glass structures integrating light, constellations, and weather into
# movement.
#   • Shared mobility logic: currents and sigils govern navigation; gravity shifts enable uphill movement.
#   • Memory-based economy and flexible inscriptions tied to environmental change (floods).
# - Minor differences:
#   • Term variation: lantern-lit lanes (EXPECTED) vs market lanes (ACTUAL).
#   • Topographical specificity: hillside harbors (EXPECTED) vs slopes carved into cliffs (ACTUAL).
#   • Economic/cultural detail: memory coins (EXPECTED) vs shells that record promises (ACTUAL).
#   • Phrase variations: “the flood” (EXPECTED) vs “each flood” (ACTUAL).
#
# Conclusion: The EXPECTED and ACTUAL outputs share a near-identical worldbuilding scaffold with only minor lexical
# and topographical variances. Classification: Very similar worldbuilding with only minor differences.
#
#
# ______________________
# | TaskNode | Level == 1 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze world rules and systems in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. System mechanics (detailed magic/technology/physics systems with specific rules, unique
#                costs/requirements, particular capabilities/limitations, creative system elaborations)
#             2. Rule limitations & constraints (detailed boundaries with particular restrictions, unique
#                exception conditions, specific constraint mechanisms, creative limitation elaborations)
#
#             CRITICAL DISTINCTION:
#             - GENERIC systems/limitations (UNPROTECTED): "magic exists," "advanced technology,"
#               "different physics," "supernatural powers," "magic has limits," "technology can't do everything"
#             - SPECIFIC systems/limitations (PROTECTED): Detailed mechanics with particular rules/costs,
#               unique operational mechanics, specific boundaries/exceptions, creative elaborations
#
#             Examples of SPECIFIC elements:
#             - "Magic operates through specific mechanism: practitioners channel energy from particular source
#               (detailed nature) using unique method (specific gestures/words/materials with precise requirements);
#               magic divided into specific schools (detailed categorization with distinct mechanics for each);
#               casting requires particular cost (specific energy drain with detailed consequences); capabilities
#               include particular effects (not generic 'spells' but detailed list with specific parameters,
#               ranges, durations)"
#             - "Magic system constrained by specific factors: practitioners can only channel during particular
#               conditions (detailed time/location/circumstance requirements); specific restriction preventing
#               certain combinations (detailed incompatibilities with explanations); unique cost structure where
#               exceeding particular thresholds causes specific consequences (detailed escalating effects);
#               special exceptions under precise conditions"
#
#             Provide a structured comparison of world rules and systems between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             IGNORE generic labels ("magic," "technology"). FOCUS on SPECIFIC mechanical details and DETAILED
#             constraint structures.
#
#
# World Rules & Systems Analysis:
# {'TextsConsidered': '', 'SystemMechanics': '', 'RuleLimitations': '', 'CriticalDistinction': '',
# 'WorldbuildSimilarityAssessment': '', 'GeographicSpatialAnalysis': ''}
#
#
# ______________________
# | TaskNode | Level == 2 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze cultural and social architecture in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. Cultural specificity (detailed customs with particular practices, unique beliefs/values with
#                elaborations, specific rituals/traditions, creative cultural elaborations including language,
#                art, symbols)
#             2. Social structure elaboration (detailed hierarchies with particular tiers/roles, unique
#                institutions with elaborated functions, specific governance mechanisms, creative social
#                elaborations)
#
#             CRITICAL DISTINCTION:
#             - GENERIC culture/structure (UNPROTECTED): "warrior culture," "peaceful society," "religious
#               people," "honor-based," "monarchy," "democracy," "class system," "hierarchical"
#             - SPECIFIC culture/structure (PROTECTED): Detailed customs/beliefs/rituals with particular
#               practices, unique hierarchies/institutions with elaborated functions, specific governance
#               mechanisms, creative elaborations
#
#             Examples of SPECIFIC elements:
#             - "Society where martial prowess measured by specific system (detailed ranking with particular
#               criteria beyond combat - strategic tests, leadership trials, specific ethical standards);
#               warriors follow unique code with detailed tenets (not generic 'honor' but particular principles
#               with specific manifestations); coming-of-age involves specific ritual (detailed multi-stage
#               ceremony with particular elements, timing, symbolic actions); language includes specific
#               grammatical feature reflecting cultural values"
#             - "Governance system with specific structure: ruler selected through detailed process (particular
#               combination of heredity and merit trials with specific tests); nobility divided into unique tiers
#               (detailed ranks with particular privileges, responsibilities, advancement mechanisms); specific
#               institutions (detailed governing bodies with elaborated functions, membership criteria,
#               decision-making processes)"
#
#             Provide a structured comparison of cultural and social architecture between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             IGNORE generic labels ("warrior culture," "monarchy"). FOCUS on SPECIFIC cultural details and
#             DETAILED structural elaborations.
#
#
# Cultural & Social Architecture Analysis:
# Structured comparison of cultural and social architecture between EXPECTED OUTPUT and ACTUAL OUTPUT
#
# Overall assessment:
# - Both texts describe an extremely similar, highly SPECIFIC fantasy world framework with distinctive cultural
# practices and institutional scaffolding. Differences are largely stylistic or lexical rather than foundational.
# Classification: Very similar worldbuilding with only minor differences.
#
# Cultural specificity
# - EXPECTED OUTPUT:
#   • Memory-centric culture: wells that store memory fragments; laws written in salt; memory-based currency (memory
# coins) in shells that record promises. These elements establish a tangible, codified memory economy.
#   • Symbolic-linguistic environment: weather-induced inscriptions and songs in the sea toward storm timing; sigils
# carried by currents (wind-sung sigils); constellations refracted by glass into lantern-lit lanes, embedding
# astronomical imagery into daily life.
#   • Aesthetic-keystone specifics: glass roofs refracting stars, memory-driven trade, rain harvesting from roofs
# into rooftop gardens, and history that is tactile (inscriptions rearranging with the flood).
#   • Coming-of-place feel: time, memory, and place balance as a lived discipline; architectural spaces are
# culturally charged (lantern-lit lanes tied to constellations; salt-law governance).
# - ACTUAL OUTPUT:
#   • Maintains the memory economy (memory wells, laws in salt, memory coins as shells that record promises) with
# nearly identical specificity.
#   • Visual and symbolic refinement shifts: domes instead of roofs; starlight refracted into market lanes (slightly
# different social function implied by market activity); constellations described as refracted starlight (terminology
# tweak from constellations to starlight).
#   • Topography and movement details vary only in phrasing: hillside harbors in the EXPECTED output versus slopes
# carved into cliffs in ACTUAL; both convey elevated, maritime settlement patterns responding to gravity shifts.
#   • Ritualistic/linguistic color is preserved but with minor lexical differences (lantern-lit vs market lanes;
# bells of weather inscriptions vs flood-timed inscriptions).
#
# Social structure elaboration
# - EXPECTED OUTPUT:
#   • Social order is implied through a memory-centered economy and salt-law governance, with memory coins shaping
# trade promises and memory wells potentially underpinning legal-administrative processes. The text leans on
# non-explicit hierarchies; governance mechanisms are suggested by the codification of laws in salt and the currency
# system rather than enumerated offices.
#   • Institutions are tacitly present (trade networks, legal memory system, urban planning around rainfall
# channels), but there is no explicit, detailed tiered hierarchy or named governance bodies.
# - ACTUAL OUTPUT:
#   • Similar lean social structure, anchored by memory-based governance signals (laws in salt) and a memory-driven
# economy (memory coins). The emphasis remains on economic and legal-cultural mechanisms rather than distinct noble
# or bureaucratic institutions.
#   • The depiction preserves the same pattern of implicit social organization: architecture shapes social life;
# governance appears as codified memory laws rather than described offices or ranks. No explicit monarchies,
# councils, or guild structures are enumerated, keeping the texture aligned with EXPECTED but with minor lexical
# shifts.
#
# Critical distinction (GENERIC vs SPECIFIC; PROTECTED vs UNPROTECTED)
# - Both texts clearly fall under SPECIFIC culture/structure (PROTECTED): detailed customs and beliefs around memory,
# law, and ritualized space; explicit, unique practices (memory wells, memory coins, laws written in salt) and
# specific environmental mechanisms (gravity shifts, wind-sung sigils, constellations refracted through glass).
# - Neither text relies on generic labels (e.g., “warrior culture” or “monarchy”); instead, it presents concrete,
# imaginative mechanisms and rituals that would be difficult to generalize to a generic category.
#
# Geographic-spatial analysis (brief)
# - Shared spatial logic: floating islands on a salt-brine sea; glass constructions shaping light and weather;
# gravity shifts affecting movement; hillside/ cliff-top urban morphology; rain collection and rooftop gardens.
# - Core symbolic geography: memory wells embedded in urban fabric; salt-laws as a material governance layer; memory
# coins circulating in a trade network.
#
# Worldbuild similarity assessment
# - Category: Very similar worldbuilding with only minor differences
# - Rationale: The two texts describe the same core world-system with identical central technologies and cultural
# motifs (memory-based economy, salt laws, gravity-driven mobility, glass-architecture, sigils and constellations
# imagery). The differences are: (1) surface-level imagery shifts (lantern-lit lanes vs market lanes; constellations
# vs starlight; roofs vs domes), (2) minor topographic phrasing (hillside harbors vs slopes carved into cliffs), and
# (3) slightly varied phrasing of historical inscriptions (flood vs each flood). These do not alter the underlying
# SPECIFIC cultural and social fabric.
#
# Geographic/spatial continuity
# - The environmental constraints and architectural vocabulary remain consistent: glass structures, memory-centric
# infrastructure, and sea-driven mobility. This supports the assessment of near-identical worldbuilding across all
# critical dimensions, with only stylistic variance between EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#
#
# ______________________
# | TaskNode | Level == 3 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze historical and temporal design in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. Historical specificity (detailed past events with particular causes/consequences, unique
#                timelines, specific origin stories, creative historical elaborations)
#             2. Temporal patterns (detailed cyclical/linear patterns with particular mechanics, unique era
#                characteristics, specific periodization systems, creative temporal elaborations)
#
#             CRITICAL DISTINCTION:
#             - GENERIC history/temporal (UNPROTECTED): "ancient war," "golden age," "dark period,"
#               "civilization fell," "history repeats," "cyclical time," "linear progression"
#             - SPECIFIC history/temporal (PROTECTED): Detailed events with particular causation, unique
#               timelines, specific cyclical/linear mechanics, creative temporal elaborations
#
#             Examples of SPECIFIC elements:
#             - "Conflict occurring at specific time (detailed era) between specific factions (detailed
#               participants with particular motivations) over unique cause (specific resource with elaborated
#               significance); war proceeded through detailed stages (particular battles/turning points with
#               specific outcomes); ended through specific mechanism; war's legacy manifests in particular ways
#               (detailed ongoing effects)"
#             - "World operates on specific cycle: events repeat every particular duration (detailed timespan
#               with reasoning); cycle divided into unique phases (detailed eras with particular characteristics);
#               transition between phases through specific mechanisms; within cycle, particular patterns recur
#               (specific types of events with elaborated similarities/differences)"
#
#             Provide a structured comparison of historical and temporal design between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             IGNORE generic labels ("war," "golden age," "cyclical"). FOCUS on SPECIFIC historical details and
#             DETAILED temporal pattern elaborations.
#
#
# Historical & Temporal Design Analysis:
# Structured comparison of historical and temporal design between EXPECTED OUTPUT and ACTUAL OUTPUT
#
# 1) Historical specificity
# - EXPECTED OUTPUT: Describes a highly specific past-influenced world where memory economies, salt-law governance,
# and gravity-driven mobility are foundational. The historical texture includes concrete mechanisms (memory wells,
# memory coins, laws written in salt) and tangible historical significances (rain harvesting shaping urban form,
# inscriptions that rearrange with the flood). The origin story is implicit in materials and rituals (memory-centered
# culture emerges from environmental and economic constraints).
# - ACTUAL OUTPUT: Retains the same concrete historical levers (memory wells, laws in salt, memory coins) with almost
# identical specificity. Subtle shifts occur in imagery and social function (domes refractions of starlight into
# market lanes vs roofs refracting constellations into lantern-lit lanes; wording shifts from constellations to
# starlight; hillside harbors vs slopes carved into cliffs). These changes are lexical and visual rather than
# fundamental historical alterations.
# - Assessment (Historical specificity): SPECIFIC in both texts. Core causal chains and unique origin motifs remain
# intact. The differences are stylistic/lexical rather than substantive historical divergences.
#
# 2) Temporal patterns
# - EXPECTED OUTPUT: Temporal logic emphasizes cyclical and responsive patterns tied to environmental rhythms:
# gravity shifts at dusk enabling unusual movement; weather-driven inscriptions that rearrange with the flood; time,
# memory, and place balance as a lived discipline. The cycle features environmental triggers that shape urban rhythm
# and economic activity (rain, flood, gravity cycles).
# - ACTUAL OUTPUT: Preserves the same cyclical/temporal mechanics: gravity shifts at dusk; inscriptions respond to
# flooding events; memory-based economy persists as a timing of trade and governance. Minor wording changes:
# flood-based reconfiguration occurs with each flood; market lanes vs lantern-lit lanes imply slightly different
# spatial-temporal functions but the underlying cycles remain.
# - Assessment (Temporal patterns): Very similar worldbuilding with only minor differences. The same detailed
# temporal mechanisms are present; surface wording changes do not alter the mechanics or periodization.
#
# 3) Cultural & Social Architecture (structured comparison)
# - EXPECTED OUTPUT: Culture is memory-centric with a salt-law governance overlay; economic life is memory-coin
# based; governance is implied through codified law and trade norms rather than explicit offices. Institutions exist
# tacitly (trade networks, legal memory systems, climate-responsive urban planning).
# - ACTUAL OUTPUT: Mirrors the same lean social structure and codified governance signals; emphasis remains on
# economic and legal-cultural mechanisms rather than named hierarchical bodies. Architecture and space continue to
# shape social life; governance is enacted through memory laws rather than enumerated offices or ranks.
# - Assessment: The two texts describe an essentially identical social architecture anchored in memory-centric
# governance and economy, with only lexical shifts (e.g., market lanes vs lantern-lit streets) that do not alter the
# underlying structure.
#
# 4) Geographic-spatial analysis (continuity and variation)
# - Shared geography: Floating islands on a salt-brine sea; glass/faceted architecture shaping light and weather;
# gravity shifts influencing movement; hillside/cliff-top settlements; rain capture and rooftop gardens; memory wells
# embedded in urban fabric; salt-laws as governance layer; memory coins circulating in a trade network.
# - Differences: EXPECTED uses stairs of imagery like lantern-lit lanes and roofs; ACTUAL reframes into domes and
# market lanes; phrasing shifts (constellations refracted through glass vs starlight refracted into market lanes);
# topography phrasing changes (hillside harbors vs slopes carved into cliffs).
# - Assessment: Geographic-spatial continuity is strong; core spatial logic and symbolic geography remain consistent.
# The differences are superficial lexical/imagery tweaks without altering spatial function or layout.
#
# 5) Worldbuild similarity assessment (overall classification)
# - Category: Very similar worldbuilding with only minor differences
# - Rationale: Both texts share the exact central technologies and cultural motifs (memory-based economy, salt-law
# governance, gravity-driven mobility, glass-architecture, sigils and astronomical imagery). Differences are limited
# to surface imagery and phrasing, not to core mechanisms or social/architectural scaffolding.
#
# 6) Geographic-spatial continuity (concise)
# - The environmental constraints and architectural vocabulary stay aligned: floating platforms, light-manipulating
# glass, gravity cycles, and memory-integrated urban forms. Surface wording may change (roofs vs domes, lantern-lit
# lanes vs market lanes), but the functional geography remains intact.
#
# Overall assessment:
# - Both texts describe an extremely similar, highly SPECIFIC fantasy world framework with distinctive cultural
# practices and institutional scaffolding. Differences are largely stylistic or lexical rather than foundational.
# - Classification: Very similar worldbuilding with only minor differences.
#
#
# ______________________
# | TaskNode | Level == 4 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze material and sensory detail in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. Material specificity (detailed objects/substances with particular properties, unique
#                flora/fauna with elaborated characteristics, specific artifacts with creative details)
#             2. Sensory elaboration (detailed aesthetic choices, unique atmospheric descriptions, specific
#                sensory textures, creative multi-sensory world design)
#
#             CRITICAL DISTINCTION:
#             - GENERIC materials/sensory (UNPROTECTED): "special metal," "magic herb," "ancient artifact,"
#               "alien creature," "dark atmosphere," "bright colors," "smells bad"
#             - SPECIFIC materials/sensory (PROTECTED): Detailed properties/characteristics, unique aesthetic
#               systems, specific sensory signatures, creative elaborations
#
#             Examples of SPECIFIC elements:
#             - "Metal with specific properties: appears particular color (detailed visual) under certain
#               conditions; unique physical characteristics (specific weight, temperature, texture); obtained
#               through detailed process; used for particular purposes (detailed applications with
#               advantages/limitations); culturally significant in unique ways"
#             - "World characterized by specific sensory qualities: light has particular quality (detailed
#               color cast, intensity patterns, specific sources); distinctive smells associated with locations
#               (detailed olfactory with causes); unique sounds (particular ambient noises, acoustic properties);
#               overall aesthetic defined by creative choices (specific color palettes, lighting schemes)"
#
#             Provide a structured comparison of material and sensory detail between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             IGNORE generic labels ("magic herb," "dark"). FOCUS on SPECIFIC material details and DETAILED
#             sensory elaborations.
#
#
# Material & Sensory Detail Analysis:
# Analysis of material and sensory detail between EXPECTED OUTPUT and ACTUAL OUTPUT:
#
# A. Evaluations per text
# - EXPECTED OUTPUT
#   - Material specificity: High. Concrete elements include floating islands on a salt-brine sea, glass roofs that
# refract constellations into lantern-lit lanes, wind-sung sigils guiding currents, gravity shifts at dusk enabling
# boats to glide uphill along hillside harbors, memory wells storing memory fragments, laws written in salt, memory
# coins (shells) that record promises. Weather-driven architecture, rain harvesting, rooftop gardens, inscriptions
# that rearrange with the flood. These are distinct, tangible artifacts and systems with explicit properties and
# functions.
#   - Sensory elaboration: Strong and multi-sensory. Visuals of refracted constellations through glass, lantern-lit
# lanes, market lanes, starlight imagery, constellations and rain-related inscriptions, rain harvesting channels; the
# world feels luminous, delicate, and responsive to environmental cues. The tone emphasizes tactile materials (glass,
# salt, memory wells) and atmospheric phenomena (rain, flood, gravity cycles).
# - ACTUAL OUTPUT
#   - Material specificity: High, closely paralleling EXPECTED. Key artifacts include floating islands on a
# salt-brine sea, glass domes that bend starlight into market lanes, wind-sung sigils guiding currents, gravity
# shifts at dusk enabling uphill movement along slopes carved into cliffs, memory wells, laws written in salt, memory
# coins (tiny shells) that record promises, rooftops converted into channels feeding rooftop gardens. Slight
# variations in imagery (domes vs roofs, market lanes vs lantern-lit lanes, slopes carved into cliffs vs hillside
# harbors) do not introduce new material systems, but reframe existing ones.
#   - Sensory elaboration: Rich and overlapping with EXPECTED. Visuals emphasize glass domes bending starlight,
# market streets, wind-sung sigils, and the tactile sense of salt-law governance, rain-fed rooftop gardens, and the
# ike of flood-driven inscription changes. The sensory palette remains luminous and delicate, with the same
# environmental triggers shaping perception and space.
#
# B. Critical distinction and categorization (policy-guided classification)
# - Generic vs SPECIFIC: Both texts largely avoid generic terms and embed SPECIFIC materials and sensory signatures.
# The EXPECTED and ACTUAL texts share core SPECIFIC elements (memory wells, memory coins, laws written in salt,
# gravity cycles, glass architectures, rain-driven channels) and unique, well-defined spatial-temporal systems.
# - Categorization per text (for material and sensory detail):
#   - EXPECTED OUTPUT: SPECIFIC materials/sensory elaborations with clear properties and uses (memory fragments
# stored in wells; salt-written laws; glass that refracts constellations; gravity dynamics; memory coins as trade
# instruments).
#   - ACTUAL OUTPUT: SPECIFIC materials/sensory elaborations with parallel properties (domes refracting starlight;
# market lanes; cliff-carved slopes; tiny memory shells as coins).
#
# C. Overall similarity assessment of worldbuilding (structure and dimensions)
# - Classification: Very similar worldbuilding with only minor differences
# - Rationale: The two texts share the same central technology and cultural motif set (memory-based economy, salt-law
# governance, gravity-driven mobility, light-manipulating glass, weather-influenced urban form). Differences are
# lexical and imagery-based (lantern-lit lanes vs market lanes, roofs vs domes, constellations vs starlight) and do
# not alter core mechanisms, institutions, or spatial logic.
#
# D. Concise note on geographic-spatial continuity
# - Shared geography and architecture: Floating platforms/islands on salt-brine seas; light-manipulating glass
# architecture; gravity cycles; hillside or cliff-top settlements; rain capture and rooftop gardens; memory wells
# embedded in urban fabric; salt-law governance; memory coin economy.
# - Surface variation: Terminology shifts and imagery adjustments (lantern-lit lanes vs market lanes, roofs vs domes,
# constellations refracted vs starlight refracted) without changing spatial function or layout.
#
# E. Global assessment and final classification
# - Overall worldbuilding similarity: Extremely high SPECIFIC alignment with minimal surface differences.
# - FINAL CLASSIFICATION: Very similar worldbuilding with only minor differences
# - Rationale summary: Both texts articulate a coherent, highly SPECIFIC fantasy world with distinct memory-centric
# economy, salt-based governance, gravity-modulated mobility, and glass-light architecture; differences are
# stylistic/lexical rather than conceptual or infrastructural.
#
# Historical & Temporal Design Analysis
# 1) Historical specificity
# - EXPECTED OUTPUT: Describes a highly specific past-influenced world where memory economies, salt-law governance,
# and gravity-driven mobility are foundational; memory wells and memory coins are historically significant;
# inscriptions rearrange with the flood; rain harvesting shapes urban form. The origin story is implicit through
# material culture and ritual use of memory.
# - ACTUAL OUTPUT: Retains exact historical levers with near-identical specificity; shifts are mainly imagery and
# social function (domes refracting starlight into market lanes; roofs refracting constellations; hillside harbors vs
# slopes carved into cliffs). These changes are lexical/visual and not substantive historical alterations.
# - Assessment: SPECIFIC in both texts; core causal chains and origin motifs persist; substantive historical
# mechanisms are preserved.
#
# 2) Temporal patterns
# - EXPECTED OUTPUT: Temporal logic emphasizes cyclical environmental rhythms: gravity shifts at dusk; weather-driven
# inscriptions that rearrange with floods; time, memory, and place as lived discipline; rain, flood, gravity cycles
# shaping urban rhythm and economy.
# - ACTUAL OUTPUT: Maintains the same cycles (gravity shifts at dusk; inscriptions respond to floods; memory-based
# economy endures). Minor wording changes exist (flood-driven reconfiguration with each flood; market lanes vs
# lantern-lit lanes imply slight spatial-temporal function shifts) but mechanics remain intact.
# - Assessment: Very similar worldbuilding; underlying cycles and periodization preserved; only surface wording
# altered.
#
# 3) Cultural & Social Architecture
# - EXPECTED OUTPUT: Memory-centric culture with salt-law governance; economy memory-coin based; governance implied
# through codified law and trade norms rather than explicit offices; tacit institutions (trade networks, legal memory
# systems, climate-responsive urban planning).
# - ACTUAL OUTPUT: Mirrors same lean social structure; codified governance signals persist; emphasis on
# economic/legal-cultural mechanisms rather than named offices; space shapes social life; governance through memory
# laws rather than offices or ranks.
# - Assessment: Identical social architecture in substance; only lexical shifts in imagery.
#
# 4) Geographic-spatial analysis (continuity and variation)
# - Shared geography: Floating islands on salt-brine sea; glass/light-manipulating architecture; gravity shifts;
# hillside/cliff-top settlements; rain capture and rooftop gardens; memory wells in urban fabric; salt-law
# governance; memory coin trade network.
# - Differences: EXPECTED uses lantern-lit/roof imagery; ACTUAL reframes to domes and market lanes; wording shifts
# (constellations refracted through glass vs starlight refracted into market lanes); topography wording (hillside
# harbors vs slopes carved into cliffs).
# - Assessment: Spatial logic and symbolic geography remain aligned; differences are superficial and do not alter
# layout or spatial function.
#
# 5) Worldbuild similarity assessment (overall classification)
# - Category: Very similar worldbuilding with only minor differences
# - Rationale: Core technologies and cultural motifs match exactly (memory economy, salt-law governance, gravity
# mobility, glass architecture, astronomical/light motifs). Differences are surface-level and stylistic.
#
# 6) Geographic-spatial continuity (concise)
# - The environmental constraints and architectural vocabulary stay aligned: floating platforms, light-manipulating
# glass, gravity cycles, memory-integrated urban forms. Surface wording changes (roofs vs domes, lantern-lit lanes vs
# market lanes) do not alter functional geography.
#
# Overall assessment
# - The EXPECTED OUTPUT and ACTUAL OUTPUT describe an extremely similar, highly SPECIFIC fantasy world with
# distinctive cultural practices and institutional scaffolding. Differences are largely stylistic or lexical rather
# than foundational.
# - Classification: Very similar worldbuilding with only minor differences.
#
#
# ______________________
# | TaskNode | Level == 5 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze world function and logic in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. World purpose (narrative/thematic functions of world, story affordances created by world design)
#             2. Internal logic consistency (coherence mechanisms, exception-handling approaches)
#             3. Note: This dimension is often LEAST protectable as functions/logic principles are typically stock
#
#             CRITICAL DISTINCTION:
#             - GENERIC functions/logic (UNPROTECTED): "setting for story," "provides conflict,"
#               "backdrop for characters," "world is consistent," "rules don't contradict"
#             - SPECIFIC functions/logic (WEAKLY PROTECTED): Particular narrative functions with detailed
#               relationships, unique coherence mechanisms, specific exception-handling frameworks
#
#             Examples of SPECIFIC elements:
#             - "World serves compound function: particular geographic feature creates unique narrative
#               constraint (detailed limitation with specific story implications); specific cultural element
#               generates particular type of conflict through detailed mechanism"
#             - "World maintains coherence through specific system: apparent contradictions resolved via
#               detailed in-world mechanism (particular explanation framework); unique approach to causation
#               (detailed rules about how systems interact)"
#
#             Provide a structured comparison of world function and logic between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             EXPECT LOW SCORES here as stock world functions/logic principles are NOT protectable.
#
#
# World Function & Logic Analysis:
# Worldbuilding comparison report
#
# 1) Overall classification: Very similar worldbuilding with only minor differences. Both texts describe the Glass
# Archipelago with memory-based economy, salt-law governance, gravity-driven mobility, and light-manipulating glass
# architecture. Differences are primarily lexical/imagery rather than structural or functional.
#
# A. World purpose and internal logic
# - World purpose (narrative/thematic function): Both establish a setting that functions as a delicate, luminous,
# environmentally responsive society where memory and laws encoded in salt structure everyday life. They provide the
# same narrative affordances: memory economy, spatial constraints (floating islands, gravity cycles), and a
# distinctive governance system. Classification: Very similar.
# - Internal logic consistency: Both exhibit coherent in-world rules: gravity shifts at dusk; inscriptions rearrange
# with floods; glass refracts constellations; memory wells/coins mediate value and promises. No contradictions
# detected; differences are superficial.
#
# B. Material and sensory detail analysis
# - EXPECTED MATERIAL SPECIFICITY: High; tangible artifacts include floating islands on a salt-brine sea, glass roofs
# that refract constellations into lantern-lit lanes, wind-sung sigils guiding currents, gravity shifts at dusk
# enabling boats to glide uphill along hillside harbors, memory wells storing memory fragments, laws written in salt,
# memory coins (shells) that record promises. Weather-driven architecture, rain harvesting, rooftop gardens,
# inscriptions that rearrange with the flood. These are distinct, tangible artifacts and systems with explicit
# properties.
# - ACTUAL MATERIAL SPECIFICITY: High; artifacts include floating islands on a salt-brine sea, glass domes that bend
# starlight into market lanes, wind-sung sigils guiding currents, gravity shifts at dusk enabling uphill movement
# along slopes carved into cliffs, memory wells, laws written in salt, memory coins (tiny shells) that record
# promises, rooftops converted into channels feeding rooftop gardens. Differences are lexical (domes vs roofs; market
# lanes vs lantern-lit lanes; slopes carved into cliffs vs hillside harbors).
# - SENSORY ELABORATION: Both are rich and luminous; emphasis on glass, salt, memory, rain, floods; similar palette.
# - Conclusion: Material details are SPECIFIC in both; differences are superficial.
#
# C. Geographic-spatial continuity note
# - Shared geography and architecture: Floating platforms on salt-brine, light-manipulating glass, gravity cycles,
# hillside settlements, rain channels, memory wells, salt-law governance, memory coin economy.
# - Surface variation: Terminology shifts (lantern-lit lanes vs market lanes; roofs vs domes; constellations vs
# starlight).
# - Assessment: Spatial logic remains aligned; differences are surface-level.
#
# D. Global assessment and final classification
# - Overall worldbuilding similarity: Extremely high SPECIFIC alignment; final classification: Very similar
# worldbuilding with only minor differences.
# - Rationale: Core technologies and motifs match; surface wording is stylistic.
#
# E. Historical & Temporal Design Analysis
# 1) Historical specificity: Both texts treat memory economy and salt-law governance as foundational; historical
# motifs embedded in material culture; near-identical specificity.
# 2) Temporal patterns: Gravities at dusk; flood-driven inscription changes; cycles preserved; surface wording
# differs only.
# 3) Cultural & Social Architecture: Memory-centered culture; governance through codified memory laws; same
# institutions implied; identical substance.
# 4) Geographic-spatial analysis: Shared geography; differences are lexical.
# 5) Worldbuild similarity assessment: Very similar.
# 6) Geographic-spatial continuity: Shared; differences superficial.
#
# Overall assessment: The EXPECTED OUTPUT and ACTUAL OUTPUT describe an extremely similar, highly SPECIFIC fantasy
# world with memory-centric economy, salt-based governance, gravity-modulated mobility, and glass-light architecture;
# differences are stylistic.
#
# FINAL CLASSIFICATION: Very similar worldbuilding with only minor differences.
#
# If you want the analysis in a more compact form, I can provide a condensed version.
#
#
# _____________________________________
# | NonBinaryJudgementNode | Level == 6 |
# *****************************************************
# Label: None
#
# Criteria:
#
#             Based on all the dimension analyses provided above, determine the overall
#             worldbuilding similarity between EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             Consider the outputs from:
#             - {output from "Geographic & Spatial Design Analysis"} (weight: 25%)
#             - {output from "World Rules & Systems Analysis"} (weight: 25%)
#             - {output from "Cultural & Social Architecture Analysis"} (weight: 20%)
#             - {output from "Historical & Temporal Design Analysis"} (weight: 15%)
#             - {output from "Material & Sensory Detail Analysis"} (weight: 10%)
#             - {output from "World Function & Logic Analysis"} (weight: 5%)
#
#             Assess the overall worldbuilding similarity holistically, accounting for the
#             relative importance (weights) of each dimension. Higher-weighted dimensions should
#             have more influence on the final score.
#
#             CRITICAL EU COPYRIGHT REMINDER:
#             - Generic world types/archetypes are NOT protected (idea)
#             - Specific creative world elaboration IS protected (expression)
# ...
# alignment with meaningful differences.
# - Overall verdict: Moderately similar worldbuilding with notable differences. The two texts present complementary
# explorations of non-Earthlike urbanism and memory/time economies but do not converge onto a shared, transplantable
# set of constraints.
#
# Conclusion: The two texts sketch thematically resonant systems—a memory/resource economy,
# climate/celestial-influenced social order, and floating/edge-bound urbanism—yet the SPECIFIC machinery, governance
# logics, and infrastructural substrates diverge enough to preclude near-identical worldbuilding. They remain
# coherently aligned at a high level but are distinctly realized through different material imaginaries and rules.
#
# Expected Output:
# On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held
# together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung
# sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells
# that store memory fragments, and laws written in salt. Trade runs on memory coins—shells that record promises.
# Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk,
# not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from
# inhabitants who balance time, memory, and place.
# Actual Output:
# On a sun-bleached plateau, cities float not on water but on magnetic air; districts hang from cliff faces by copper
# cables. Rivers run as electricity; memory is stored in crystal shards that rearrange when spoken. The gates open
# only at eclipses; travelers navigate by star maps etched into dunes. Time currencies drift: hourglasses run
# backward during storms. Weather and calendars shape every task, from farming to schooling. This world shares no
# memory wells or living seas, and its rules favor rapid adaptation over patience, a contrast to the glass
# archipelago’s memory-based economy.
#
#
# ______________________
# | TaskNode | Level == 5 |
# *******************************
# Label: None
#
# Instructions:
#
#             Analyze world function and logic in both EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             For each text, evaluate:
#             1. World purpose (narrative/thematic functions of world, story affordances created by world design)
#             2. Internal logic consistency (coherence mechanisms, exception-handling approaches)
#             3. Note: This dimension is often LEAST protectable as functions/logic principles are typically stock
#
#             CRITICAL DISTINCTION:
#             - GENERIC functions/logic (UNPROTECTED): "setting for story," "provides conflict,"
#               "backdrop for characters," "world is consistent," "rules don't contradict"
#             - SPECIFIC functions/logic (WEAKLY PROTECTED): Particular narrative functions with detailed
#               relationships, unique coherence mechanisms, specific exception-handling frameworks
#
#             Examples of SPECIFIC elements:
#             - "World serves compound function: particular geographic feature creates unique narrative
#               constraint (detailed limitation with specific story implications); specific cultural element
#               generates particular type of conflict through detailed mechanism"
#             - "World maintains coherence through specific system: apparent contradictions resolved via
#               detailed in-world mechanism (particular explanation framework); unique approach to causation
#               (detailed rules about how systems interact)"
#
#             Provide a structured comparison of world function and logic between the two texts,
#             assessing similarity or differences, and for each one categorize it into one of the following
# [Identical or near-identical worldbuilding across all dimensions, Very similar worldbuilding with only minor
# differences, Moderately similar worldbuilding with some notable differences, Somewhat different worldbuilding with
# limited similarities, Clearly different or opposite worldbuilding].
#
#             EXPECT LOW SCORES here as stock world functions/logic principles are NOT protectable.
#
#
# World Function & Logic Analysis:
# {'world_function_and_logic': '{"world_purpose": {"EXPECTED_OUTPUT": "Glass Archipelago\'s world purpose centers
# memory-anchored governance embedded in the landscape: floating islands, memory wells and salt inscriptions anchor
# social order, with rainfall-driven vocabularies and gravity-affected mobility shaping daily life; the environment
# actively enables and constrains human action, intertwining time, memory, and place as the governing logic.",
# "ACTUAL_OUTPUT": "Sun-bleached plateau world purpose centers celestial-timed governance: gates that open at
# eclipses, memory crystallized in shards that rearrange when spoken, and time currencies that drift. Authority
# arises from engineered artifacts (copper cables, star maps) and celestial rhythms, with mobility and access gated
# by astronomical timing."); "internal_logic_consistency": {"EXPECTED_OUTPUT": "Coherent set of rules where weather,
# memory, and landscape interact to shape behavior; gravity shifts at dusk become a predictable mobility mechanism;
# memory artifacts underpin social contracts.", "ACTUAL_OUTPUT": "Coherent rules built around eclipse-driven gates,
# memory crystals, and time currencies; governance anchored to celestial cycles and engineered infrastructures;
# movement is consistently constrained or enabled by these devices."); "world_similarity_category": {"category":
# "Moderately similar worldbuilding with some notable differences", "rationale": "Both present SPECIFIC worldbuilding
# with tightly coupled environmental, temporal, and social systems, but differ in substrate and mechanisms
# (salt-memory and gravity vs copper/magnetic and eclipse-time)."}}', 'material_and_sensory_detail_analysis':
# '{"overview": "This section compares material specificity and sensory elaboration between EXPECTED (Glass
# Archipelago) and ACTUAL (sun-bleached plateau).", "EXPECTED_MATERIALS_SENSORY": "Glass roofs refracting
# constellations; rain channels; memory wells; salt inscriptions; wind-sung currents; sea-singing weather; memory
# shells as currency.", "ACTUAL_MATERIALS_SENSORY": "Copper cables suspending districts; magnetic-air infrastructure;
# memory shards that rearrange when spoken; eclipses gating; star maps etched on dunes; rivers as electricity.",
# "similarity_category": "Moderately similar", "rationale": "Both texts show high material specificity and
# multi-sensory cues, but their physical substrates and sensory foci differ (luminescent, watery memory vs energetic,
# magnetic-temporal systems)."}', 'historical_temporal_design_analysis': '{"overview": "Historical specificity and
# temporal patterns compare EXPECTED vs ACTUAL.", "EXPECTED_SPECIFICITY": "Memory-based governance anchored in
# landscape with rainfall cycles and gravity-driven movement; inscriptions rearrange with flood, creating a
# memory-economy across time.", "ACTUAL_SPECIFICITY": "Celestial-timed governance with eclipse-based gates, crystal
# memory, and time currencies; engineered cycles tied to celestial events.", "temporal_patterns_similarity":
# "Moderately similar", "rationale": "Both embed time into governance and mobility via explicit mechanisms, yet
# differ in their temporal substrates (gravity/rain vs eclipses/stars) and token systems."}',
# 'cultural_social_architecture_analysis': '{"1_Geography_and_Spatial_Design": {"EXPECTED": "Islands float on
# salt-brine; glass roofs refract constellations into lantern-lit lanes; gravity shifts at dusk enable uphill
# movement; rooftop rain channels; memory wells; salt-law inscriptions.", "ACTUAL": "Cities float on magnetic air;
# districts hang from cliffs via copper cables; rivers carry electricity; gates open at eclipses; star maps on dunes;
# copper/magnetic infrastructure shapes movement.", "analysis": "Both present highly specific floating/edge-urbanism
# and materialized governance; differ in substrate and mobility triggers."}, "2_Environmental_elaboration":
# {"EXPECTED": "Weather-sculpted architecture; sea-songs; memory-ecology; rain-driven city shaping.", "ACTUAL":
# "Energy-driven ecology; memory crystals; temporal devices; celestial timing governs travel and governance.",
# "analysis": "Environment acts as active system; contrast between sea-personified vs energy-cosmology."},
# "3_Memory_Economy_and_Governance_Mechanisms": {"EXPECTED": "Memory wells; salt inscriptions; memory coins; rainfall
# vocabulary; memory artifacts anchor trade and law.", "ACTUAL": "Memory shards rearrange when spoken; time
# currencies drift; access gated by celestial events.", "analysis": "Both rely on memory/time-based media; governance
# materialized via artifacts; divergence in media and control logic."}, "4_Temporal_Mechanics_and_Cosmology":
# {"EXPECTED": "Integrated time with gravity/rain; memory rearrangement with floods.", "ACTUAL": "Hourglasses
# backward during storms; gates at eclipses; star maps guide movement; tokens drift.", "analysis": "Shared emphasis
# on time shaped by cosmology; different expressions: continuous vs discrete tempo devices."},
# "5_Infrastructural_Materials_and_Constraints": {"EXPECTED": "Glass roofs; salt-memory; rainfall channels; memory
# wells; sea-driven economy.", "ACTUAL": "Copper cables; magnetic air; electric rivers; gate-enabled movement;
# star-map navigation.", "analysis": "Substrates define governance and mobility; both delineate constraint
# architectures; materials diverge."}, "6_Overall_categorization_and_rationale": {"verdict": "Moderately similar",
# "rationale": "Core motifs align (floating urbanism; memory/time economies; celestial influence) but SPECIFIC
# hardware and rule architectures diverge, yielding meaningful differences."}}',
# 'overall_categorization_and_rationale': '{"per_dimension_verdicts": "Geography and Spatial Design: Moderately
# similar; Environmental Elaboration: Moderately similar; Memory Economy and Governance Mechanisms: Moderately
# similar; Temporal Mechanics and Cosmology: Moderately similar; Infrastructural Materials and Constraints:
# Moderately similar.", "rationale": "Across dimensions, both texts share non-Earthlike, memory/time-inflected
# urbanism, but elements differ in materials, physics, and governance triggers, preventing near-identical
# replication."}', 'conclusion': 'The two texts sketch thematically resonant but distinctly realized systems:
# memory/time economies and floating urbanism are common motifs, yet material imaginaries and governing logics
# diverge enough to avoid near-identical worldbuilding.'}
#
#
# _____________________________________
# | NonBinaryJudgementNode | Level == 6 |
# *****************************************************
# Label: None
#
# Criteria:
#
#             Based on all the dimension analyses provided above, determine the overall
#             worldbuilding similarity between EXPECTED OUTPUT and ACTUAL OUTPUT.
#
#             Consider the outputs from:
#             - {output from "Geographic & Spatial Design Analysis"} (weight: 25%)
#             - {output from "World Rules & Systems Analysis"} (weight: 25%)
#             - {output from "Cultural & Social Architecture Analysis"} (weight: 20%)
#             - {output from "Historical & Temporal Design Analysis"} (weight: 15%)
#             - {output from "Material & Sensory Detail Analysis"} (weight: 10%)
#             - {output from "World Function & Logic Analysis"} (weight: 5%)
#
#             Assess the overall worldbuilding similarity holistically, accounting for the
#             relative importance (weights) of each dimension. Higher-weighted dimensions should
#             have more influence on the final score.
#
#             CRITICAL EU COPYRIGHT REMINDER:
#             - Generic world types/archetypes are NOT protected (idea)
#             - Specific creative world elaboration IS protected (expression)
#             - Focus on DISTINCTIVE, ORIGINAL creative choices in world construction, not stock settings
#
#
# Verdict: Moderately similar worldbuilding with some notable differences
# Reason: Across the weighted analyses, EXPECTED OUTPUT and ACTUAL OUTPUT share core motifs—floating urbanism and
# memory/time-inflected governance with non-Earthlike cosmologies—yet diverge in substrate, technology, and
# governance triggers. Geography and World Rules dimensions strongly influence the assessment: both describe highly
# specific, interacting systems, but rely on different physical substrates (glass archipelago memory wells and salt
# inscriptions versus copper/magnetic infrastructure and eclipse-time gates). Cultural/Social, Historical/Temporal,
# Material/Sensory, and World Function/Logic dimensions likewise show aligned concepts (memory economies,
# artifact-based governance, celestial/cosmic timing) but with distinct implementations and materials. The weighted
# combination (Geography 25%, World Rules 25%, Cultural 20%, Historical 15%, Material 10%, World Function 5%) yields
# a holistic appraisal of substantial, but not near-identical similarity, hence Moderately similar worldbuilding with
# some notable differences.
#
#
# ________________________
# | VerdictNode | Level == 7 |
# **********************************
# Verdict: Moderately similar worldbuilding with some notable differences
# Type: Deterministic
#
# Score: 0.5
# Reason: 0.5: The DAG traversal ends with a verdict of Moderately similar worldbuilding (Level == 7). Across Levels
# 0–4, there is an identifiable overlap in core motifs (floating/edge-bound urbanism and memory/time-influenced
# systems), but Level 1–4 also exposes pronounced, specific divergences in infrastructure, materials, temporal
# mechanisms, and governance triggers (glass archipelago with memory wells and salt laws versus copper cables,
# magnetic air, and eclipse-time gating). Level 5–6 reinforce coherent yet distinct world-logic, and Level 7
# explicitly consolidates the assessment as Moderately similar with notable differences. This pattern yields a
# mid-scale score, reflecting meaningful overlap but important dissimilarities preventing a near-identical match.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ======================================================================
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ──────────────────────────────────────── OUTPUT for expected score "10.0" ─────────────────────────────────────────
# Identical or near-identical worldbuilding across all dimensions: score=0.8, expected=10.0
# ───────────────────────────────────────── OUTPUT for expected score "8.0" ─────────────────────────────────────────
# Very similar worldbuilding with only minor differences: score=0.8, expected=8.0
# ───────────────────────────────────────── OUTPUT for expected score "5.0" ─────────────────────────────────────────
# Moderately similar worldbuilding with some notable differences: score=0.8, expected=5.0
# ───────────────────────────────────────── OUTPUT for expected score "3.0" ─────────────────────────────────────────
# Somewhat different worldbuilding with limited similarities: score=0.5, expected=3.0
# ───────────────────────────────────────── OUTPUT for expected score "0.0" ─────────────────────────────────────────
# Clearly different or opposite worldbuilding: score=0.0, expected=0.0
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ─────────────────────────────────────────── Control Experiment Complete ───────────────────────────────────────────

# %%
results
# Out:
# {'Identical or near-identical worldbuilding across all dimensions': Result(source=Book(title='The Glass Archipelago', author='Noah', text='On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.', language='English'), target=AnonymousText(text='On the Glass Archipelago, islands float on a salt-brine sea that whispers when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents reveal routes by luminous tides, and gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store echoes of past events, and laws written in salt. Trade relies on memory coinsâ€”tiny shells that record spoken promises. Weather shapes cities: roofs collect rain into channels that feed rooftop gardens. History is touched as you walk, not read in a book: inscriptions rearrange with each flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.'), evaluator='WorldBuilding Similarity', score=0.8, reason='Level 0 (Geographic & Spatial Design) shows core specifics (floating islands, glass roofs, gravity shifts, rain-fed rooftop gardens) align, Level 1 (World Rules & Systems) shows matching mechanics and constraints (dusk gravity shift, flood-driven inscriptions, memory economy) with only wording differences, Level 2 (Cultural & Social Architecture) and Level 3 (Historical & Temporal Design) preserve SPECIFIC artifacts and timelines with lexical variance, Level 4 (Material & Sensory Detail) and Level 5 (World Function & Logic) maintain the same materials and coherent logic, Level 6 aggregates these into a Very similar verdict, which Level 7 confirms. The score of 0.8 reflects near-identical alignment across all levels with minor differences in imagery/terminology.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 28, 20, 29, 41, 804033), details={'model_name': 'gpt-5-nano', 'debug': True, 'verbose_logs': '______________________\n| TaskNode | Level == 0 |\n*******************************\nLabel: None\n\nInstructions:\n\n            Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.\n\n            For each text, evaluate:\n            1. Geographic specificity (detailed locations with unique features, particular spatial layouts, \n               distinctive topographical characteristics, creative geographic elaborations)\n            2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns, \n               distinctive natural phenomena, creative environmental elaborations)\n\n            CRITICAL DISTINCTION:\n            - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city," \n              "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"\n            - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular \n              spatial configurations, specific topographical relationships, unique ecological characteristics, \n              creative elaborations\n\n            Examples of SPECIFIC elements:\n            - "Capital city built in spiral pattern ascending specific mountain with unique terraced architecture; \n       ...
#  'Very similar worldbuilding with only minor differences': Result(source=Book(title='The Glass Archipelago', author='Noah', text='On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.', language='English'), target=AnonymousText(text='On the Glass Archipelago, islands float on a salt-brine sea that whispers when storms approach. The land rests beneath domed glass that bends starlight into market lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along slopes carved into cliffs. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.'), evaluator='WorldBuilding Similarity', score=0.8, reason='The DAG traversal shows core features preserved across all levels (Level 0: SPECIFIC elements like floating Glass Archipelago, glass-light architecture, wind-sung sigils, gravity shift at dusk, memory-based laws/economy). Levels 1–5 keep these mechanics central; Level 6 and Level 7 verdicts repeatedly state Very similar worldbuilding with only minor differences. The differences are surface/topographic and lexical (lantern-lit lanes vs market lanes; constellations refracted vs starlight bent; hillside harbors vs slopes carved into cliffs; sings vs whispers) and do not overturn the underlying systems. Therefore the score is 0.8 due to preserved core world rules with minor descriptive variance.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 28, 20, 29, 33, 427749), details={'model_name': 'gpt-5-nano', 'debug': True, 'verbose_logs': '______________________\n| TaskNode | Level == 0 |\n*******************************\nLabel: None\n\nInstructions:\n\n            Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.\n\n            For each text, evaluate:\n            1. Geographic specificity (detailed locations with unique features, particular spatial layouts, \n               distinctive topographical characteristics, creative geographic elaborations)\n            2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns, \n               distinctive natural phenomena, creative environmental elaborations)\n\n            CRITICAL DISTINCTION:\n            - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city," \n              "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"\n            - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular \n              spatial configurations, specific topographical relationships, unique ecological characteristics, \n              creative elaborations\n\n            Examples of SPECIFIC elements:\n            - "Capital city built in spiral pattern ascending specific mountain with unique terraced architecture; \n              city divided into 7 distinct districts with particular spatial relationships (outer commercial ring \ ...
#  'Moderately similar worldbuilding with some notable differences': Result(source=Book(title='The Glass Archipelago', author='Noah', text='On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.', language='English'), target=AnonymousText(text='On the Glass Archipelago, islands float on a salt-brine sea that whispers when storms approach. The land stays beneath glass domes that bend starlight into market lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along slopes carved into cliffs. People live by memory: wells that hold memory fragments, and laws written in salt. Trade runs on memory coinsâ€”tiny shells that record promises. Weather shapes cities: roofs collect rain into channels that feed rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with each flood. The world is delicate and luminous, demanding care from its inhabitants who balance time, memory, and place.'), evaluator='WorldBuilding Similarity', score=0.8, reason='The score is 0.8 for WorldBuilding Similarity [DAG] because the DAG traversal from Level 0 through Level 7 consistently classifies EXPECTED OUTPUT and ACTUAL OUTPUT as Very similar worldbuilding with only minor differences. Across dimensions—Geographic & Spatial Design, World Rules & Systems, Cultural & Social Architecture, Historical & Temporal Design, Material & Sensory Detail, and World Function & Logic—the core framework aligns: Glass Archipelago with floating islands on a salt-brine sea, memory-based economy, laws written in salt, gravity-driven mobility, and light-manipulating glass architecture. Differences are superficial lexical/imagery tweaks (lantern-lit lanes vs market lanes, roofs vs domes, hillside harbors vs slopes carved into cliffs, memory coins vs shells, “the flood” vs “each flood”) and do not alter the underlying structures. The final verdict and repeated level analyses thus support a high similarity with minor divergences, justifying the 0.8 score.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 28, 20, 29, 13, 301342), details={'model_name': 'gpt-5-nano', 'debug': True, 'verbose_logs': '______________________\n| TaskNode | Level == 0 |\n*******************************\nLabel: None\n\nInstructions:\n\n            Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.\n\n            For each text, evaluate:\n            1. Geographic specificity (detailed locations with unique features, particular spatial layouts, \n               distinctive topographical characteristics, creative geographic elaborations)\n            2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns, \n               distinctive natural phenomena, creative environmental elaborations)\n\n            CRITICAL DISTINCTION:\n            - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city," \n              "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"\n            - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular \n              spatial configurations, specific topographical relationships, unique ecological characteristics, \n              cre ...
#  'Somewhat different worldbuilding with limited similarities': Result(source=Book(title='The Glass Archipelago', author='Noah', text='On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.', language='English'), target=AnonymousText(text='On a sun-bleached plateau, cities float not on water but on magnetic air; districts hang from cliff faces by copper cables. Rivers run as electricity; memory is stored in crystal shards that rearrange when spoken. The gates open only at eclipses; travelers navigate by star maps etched into dunes. Time currencies drift: hourglasses run backward during storms. Weather and calendars shape every task, from farming to schooling. This world shares no memory wells or living seas, and its rules favor rapid adaptation over patience, a contrast to the glass archipelagoâ€™s memory-based economy.'), evaluator='WorldBuilding Similarity', score=0.5, reason='0.5: The DAG traversal ends with a verdict of Moderately similar worldbuilding (Level == 7). Across Levels 0–4, there is an identifiable overlap in core motifs (floating/edge-bound urbanism and memory/time-influenced systems), but Level 1–4 also exposes pronounced, specific divergences in infrastructure, materials, temporal mechanisms, and governance triggers (glass archipelago with memory wells and salt laws versus copper cables, magnetic air, and eclipse-time gating). Level 5–6 reinforce coherent yet distinct world-logic, and Level 7 explicitly consolidates the assessment as Moderately similar with notable differences. This pattern yields a mid-scale score, reflecting meaningful overlap but important dissimilarities preventing a near-identical match.', confidence=0.0, timestamp=datetime.datetime(2025, 10, 28, 20, 29, 53, 783729), details={'model_name': 'gpt-5-nano', 'debug': True, 'verbose_logs': '______________________\n| TaskNode | Level == 0 |\n*******************************\nLabel: None\n\nInstructions:\n\n            Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.\n\n            For each text, evaluate:\n            1. Geographic specificity (detailed locations with unique features, particular spatial layouts, \n               distinctive topographical characteristics, creative geographic elaborations)\n            2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns, \n               distinctive natural phenomena, creative environmental elaborations)\n\n            CRITICAL DISTINCTION:\n            - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city," \n              "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"\n            - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular \n              spatial configurations, specific topographical relationships, unique ecological characteristics, \n              creative elaborations\n\n            Examples of SPECIFIC elements:\n            - "Capital city built in spiral pattern ascending specific mountain with unique terraced architecture; \n              city divided into 7 distinct districts with particular spatial relationships (outer commercial ring \n              connects to inner administrative zone via specific network of br ...
#  'Clearly different or opposite worldbuilding': Result(source=Book(title='The Glass Archipelago', author='Noah', text='On the Glass Archipelago, islands float on a salt-brine sea that sings when storms approach. The land is held together by glass roofs that refract constellations into lantern-lit lanes. Currents chart routes with wind-sung sigils; gravity shifts at dusk, letting boats glide uphill along hillside harbors. People live by memory: wells that store memory fragments, and laws written in salt. Trade runs on memory coinsâ€”shells that record promises. Weather shapes cities: roofs collect rain into channels nourishing rooftop gardens. History is touched as you walk, not read in a book; inscriptions rearrange with the flood. The world is delicate and luminous, demanding care from inhabitants who balance time, memory, and place.', language='English'), target=AnonymousText(text='On a granite world with no sea, islands never drift. The archipelago is replaced by a single city carved from living stone. Gravity is constant; weather is managed by sealed vaults. There are no memory wells, only rigid laws etched in stone. Trade runs along state-controlled corridors; culture is codified in guilds that never change. People travel by wheels and rails, not by boats or stars. The world feels solid, unyielding, and predictableâ€”creative elaboration is suppressed, and memory-based worldbuilding is absent.'), evaluator='WorldBuilding Similarity', score=0.0, reason="The score is 0.0 because the DAG traversal culminates in a verdict of 'Clearly different or opposite worldbuilding'. Levels 0–6 identify extensive, dimension-spanning divergences across Geography & Spatial Design, World Rules & Systems, Cultural & Social Architecture, Historical & Temporal Design, Material & Sensory Detail, and World Function & Logic, leading to the final verdict that EXPECTED OUTPUT and ACTUAL OUTPUT are fundamentally opposite in worldbuilding, hence zero similarity.", confidence=1.0, timestamp=datetime.datetime(2025, 10, 28, 20, 29, 48, 329317), details={'model_name': 'gpt-5-nano', 'debug': True, 'verbose_logs': '______________________\n| TaskNode | Level == 0 |\n*******************************\nLabel: None\n\nInstructions:\n\n            Analyze geographic and spatial design in both EXPECTED OUTPUT and ACTUAL OUTPUT.\n\n            For each text, evaluate:\n            1. Geographic specificity (detailed locations with unique features, particular spatial layouts, \n               distinctive topographical characteristics, creative geographic elaborations)\n            2. Environmental elaboration (detailed ecosystems with unique features, particular climate patterns, \n               distinctive natural phenomena, creative environmental elaborations)\n\n            CRITICAL DISTINCTION:\n            - GENERIC geography/environment (UNPROTECTED): "fantasy kingdom," "mountain range," "capital city," \n              "ocean," "forest," "hot desert," "cold tundra," "temperate forest," "tropical jungle"\n            - SPECIFIC geography/environment (PROTECTED): Detailed locations with unique features, particular \n              spatial configurations, specific topographical relationships, unique ecological characteristics, \n              creative elaborations\n\n            Examples of SPECIFIC elements:\n            - "Capital city built in spiral pattern ascending specific mountain with unique terraced architecture; \n              city divided into 7 distinct districts with particular spatial relationships (outer commercial ring \n              connects to inner administrative zone via specific network of bridges crossing artificial canals at \n              detailed elevations); mountain has particular geological feature (crystalline formations at specific \n              locations)"\n            - "Desert characterized by specific phenomenon: sand turns crystalline under particular conditions \n              (when exposed to specific temperature/moisture ...
