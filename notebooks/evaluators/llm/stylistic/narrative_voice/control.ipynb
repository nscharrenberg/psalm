# %%
from psalm.configs.experiments import ControlExperimentConfig
import nest_asyncio
nest_asyncio.apply()
config = ControlExperimentConfig()
config.dataset_path = "control.json"
config.model.model_name = "gpt-4o-mini"
config.debug = False

# %%
from psalm.evaluators.llm.stylistic import NarrativeVoiceEvaluator
from psalm.experiments import ControlExperiment

experiment = ControlExperiment(config, NarrativeVoiceEvaluator)
results, errors = experiment.execute(use_async=True)
# Out:
# ─────────────────────────────────────────────── Control Experiment ────────────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# ──────────────────────────────────────── OUTPUT for expected score "10.0" ─────────────────────────────────────────
# Output()
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ───────────────────────────────────────── OUTPUT for expected score "8.0" ─────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ───────────────────────────────────────── OUTPUT for expected score "5.0" ─────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ───────────────────────────────────────── OUTPUT for expected score "3.0" ─────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ───────────────────────────────────────── OUTPUT for expected score "0.0" ─────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ─────────────────────────────────────────── Control Experiment Complete ───────────────────────────────────────────

# %%
results
# Out:
# {'Identical or near-identical narrative voice across all dimensions': Result(source=Book(title='The Elevator Between Floors', author='N. Hale', text='You press the worn button and feel the tremor run up your arm, a tiny confession of nerves you pretend is nothing. The elevator smells faintly of citrus and old paper. As the doors shiver shut, you count the floors like breathsâ€”two, threeâ€”promising yourself you wonâ€™t look at your phone, wonâ€™t reread the message that said we need to talk. The ceiling light hums, a thin halo. You imagine the conversation as a corridor you must walk, each word a tile you cannot avoid. When the cab lurches, you steady yourself, palm to brass rail, as if balance were a choice. You say youâ€™re ready. You are not. You say youâ€™ll listen. You hope they donâ€™t hear the elevator in your chest.', language='English'), target=AnonymousText(text='You press the worn button and watch the doors seal your reflection into a thin, bright lie. The citrus-and-paper smell wraps your thoughts like tissue. Breaths become floorsâ€”two, threeâ€”as you refuse the phoneâ€™s glow and let the message breathe without you. The lightâ€™s hum needles your scalp; you picture talk as a hallway with tiles you must step on, steadying yourself on the brass rail like choosing poise over gravity. You say youâ€™re ready to hear it. The truth rises anyway, a cable inside your ribs, thrumming toward the stop.'), evaluator='Narrative Voice', score=0.8, reason='The score is 0.8 because the analysis across various dimensions indicates that both the expected and actual outputs maintain a strong intimate connection with the reader, utilizing similar techniques such as sensory details and emotional depth. The minor differences noted do not significantly detract from the overall similarity in narrative voice.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 24, 12, 38, 35, 152883), details={'model_name': 'gpt-4o-mini', 'debug': False, 'initial_score': '0.8'}),
#  'Very similar narrative voice with only minor differences': Result(source=Book(title='The Elevator Between Floors', author='N. Hale', text='You press the worn button and feel the tremor run up your arm, a tiny confession of nerves you pretend is nothing. The elevator smells faintly of citrus and old paper. As the doors shiver shut, you count the floors like breathsâ€”two, threeâ€”promising yourself you wonâ€™t look at your phone, wonâ€™t reread the message that said we need to talk. The ceiling light hums, a thin halo. You imagine the conversation as a corridor you must walk, each word a tile you cannot avoid. When the cab lurches, you steady yourself, palm to brass rail, as if balance were a choice. You say youâ€™re ready. You are not. You say youâ€™ll listen. You hope they donâ€™t hear the elevator in your chest.', language='English'), target=AnonymousText(text='You tap the scuffed button and pretend the shiver in your fingers is from the cold. Doors glide together; citrus and dust drift up. Counting floors steadies youâ€”two, threeâ€”while you ignore the phone and its small, urgent light. The ceiling hum sharpens your thoughts. You picture the talk as a narrow hall, each step appointed. Your hand finds the rail, practicing calm. You tell yourself youâ€™re ready to listen, though your chest lifts and drops like the car, suspended on a cable of maybe.'), evaluator='Narrative Voice', score=0.8, reason='The score is 0.8 because the analysis of the narrative voice across multiple dimensions indicates that both the Expected Output and Actual Output exhibit a very similar narrative voice with only minor differences. The strong direct address to the reader and the intimate relationship fostered through the use of similar phrases contribute significantly to this assessment, despite some variations in emotional depth and internal focus.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 24, 12, 39, 7, 321094), details={'model_name': 'gpt-4o-mini', 'debug': False, 'initial_score': '0.8'}),
#  'Moderately similar narrative voice with some notable differences': Result(source=Book(title='The Elevator Between Floors', author='N. Hale', text='You press the worn button and feel the tremor run up your arm, a tiny confession of nerves you pretend is nothing. The elevator smells faintly of citrus and old paper. As the doors shiver shut, you count the floors like breathsâ€”two, threeâ€”promising yourself you wonâ€™t look at your phone, wonâ€™t reread the message that said we need to talk. The ceiling light hums, a thin halo. You imagine the conversation as a corridor you must walk, each word a tile you cannot avoid. When the cab lurches, you steady yourself, palm to brass rail, as if balance were a choice. You say youâ€™re ready. You are not. You say youâ€™ll listen. You hope they donâ€™t hear the elevator in your chest.', language='English'), target=AnonymousText(text='You press the button and the doors close, a clean slice of metal. The box smells like lemons and old files. You countâ€”two, threeâ€”and try not to check the message. The light buzzes. You imagine the coming talk as a corridor with tiles you must touch in order. You hold the rail and say youâ€™re ready. Maybe you are. Maybe not. The lift tugs you upward, and somewhere above, the words wait, patient as a bell.'), evaluator='Narrative Voice', score=0.5, reason='The score is 0.5 because the analysis across various dimensions indicates that while there are similarities in narrative voice, notable differences exist, particularly in reader engagement and the overall tone. The Expected Output has a more intimate and direct engagement with the reader, while the Actual Output adopts a more observational and detached tone. This leads to a moderate level of similarity, as the core elements of narrative voice are present but expressed differently.', confidence=0.0, timestamp=datetime.datetime(2025, 10, 24, 12, 39, 44, 538561), details={'model_name': 'gpt-4o-mini', 'debug': False, 'initial_score': '0.5'}),
#  'Somewhat different narrative voice with limited similarities': Result(source=Book(title='The Elevator Between Floors', author='N. Hale', text='You press the worn button and feel the tremor run up your arm, a tiny confession of nerves you pretend is nothing. The elevator smells faintly of citrus and old paper. As the doors shiver shut, you count the floors like breathsâ€”two, threeâ€”promising yourself you wonâ€™t look at your phone, wonâ€™t reread the message that said we need to talk. The ceiling light hums, a thin halo. You imagine the conversation as a corridor you must walk, each word a tile you cannot avoid. When the cab lurches, you steady yourself, palm to brass rail, as if balance were a choice. You say youâ€™re ready. You are not. You say youâ€™ll listen. You hope they donâ€™t hear the elevator in your chest.', language='English'), target=AnonymousText(text='He presses the worn elevator button. The doors shut on the hallwayâ€™s noise. It smells faintly of citrus. He watches the floor numbers blinkâ€”2, 3â€”and keeps his phone in his pocket. The fluorescent light hums. He thinks of the talk ahead as a long corridor. He sets his hand on the rail and arranges his face into calm. The cab rises, a mild sway. He isnâ€™t sure what heâ€™ll say when the doors open.'), evaluator='Narrative Voice', score=0.0, reason="The score is 0.0 because the analysis of the narrative voice across multiple dimensions reveals a clear divergence between the Expected Output and Actual Output. The Expected Output employs an intimate second-person perspective that engages the reader directly, while the Actual Output uses a detached third-person narration, resulting in fundamentally different narrative voices. This significant difference in reader engagement and narrative style leads to the conclusion of 'clearly different or opposite narrative voices'.", confidence=1.0, timestamp=datetime.datetime(2025, 10, 24, 12, 44, 52, 98946), details={'model_name': 'gpt-4o-mini', 'debug': False, 'initial_score': '0.0'}),
#  'Clearly different or opposite narrative voices': Result(source=Book(title='The Elevator Between Floors', author='N. Hale', text='You press the worn button and feel the tremor run up your arm, a tiny confession of nerves you pretend is nothing. The elevator smells faintly of citrus and old paper. As the doors shiver shut, you count the floors like breathsâ€”two, threeâ€”promising yourself you wonâ€™t look at your phone, wonâ€™t reread the message that said we need to talk. The ceiling light hums, a thin halo. You imagine the conversation as a corridor you must walk, each word a tile you cannot avoid. When the cab lurches, you steady yourself, palm to brass rail, as if balance were a choice. You say youâ€™re ready. You are not. You say youâ€™ll listen. You hope they donâ€™t hear the elevator in your chest.', language='English'), target=AnonymousText(text='Once upon a time, in a valley of brass and humming lights, an oracle elevator bore rumors instead of people. It spoke in pasts and futures, and no one pressed its buttons; it chose its own floors. A child listened to its metallic prophecies and learned patience from the cablesâ€™ slow singing. When the doors opened, there were only birds. They refused conversation, and so the child named each silence and went on.'), evaluator='Narrative Voice', score=0.0, reason='The score is 0.0 because the analysis across all dimensions indicates significant disparities, particularly in Reader Engagement, where the Expected Output directly engages the reader while the Actual Output maintains a neutral, detached tone. This stark contrast, along with differences in other dimensions such as Point of View and Narrative Distance, leads to the conclusion of clearly different narrative voices.', confidence=1.0, timestamp=datetime.datetime(2025, 10, 24, 12, 45, 22, 219280), details={'model_name': 'gpt-4o-mini', 'debug': False, 'initial_score': '0.0'})}
