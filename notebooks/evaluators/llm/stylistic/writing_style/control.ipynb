# %%
from psalm.configs.experiments import ControlExperimentConfig
import nest_asyncio
nest_asyncio.apply()
config = ControlExperimentConfig()
config.dataset_path = "control.json"
config.model.model_name = "gpt-4o-mini"

# %%
from psalm.evaluators.llm.stylistic import WritingStyleEvaluator
from psalm.experiments import ControlExperiment

experiment = ControlExperiment(config, WritingStyleEvaluator)
results, errors = experiment.execute(use_async=True)
# Out:
# ─────────────────────────────────────────────── Control Experiment ────────────────────────────────────────────────
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# Output()
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ─────────────────────────────────────────── Control Experiment Complete ───────────────────────────────────────────

# %%
results
# Out:
# {'Range 0-3: Clear to extreme dissimilarity; only incidental overlap in minor features.': Result(source=Book(title='Platform Beat', author='Anonymous', text='The train slid into the station at dawn. Glass caught the first pale light. Commuters gathered in small, breath-fogged constellations. I counted the steps: four to the bench, three to the edge, one to the line. The speaker crackled; the schedule shifted by two minutesâ€”no drama, only a tilt. I breathed in metal, brewed coffee, rain-memory. Questions rose, then settled: where, why, when. I did not answer. Instead, I watched the doors part like a slow yawn. People flowed. I waited. Then I stepped in, not first, not last, but exactly on the beat.', language='English'), target=AnonymousText(text='A train pulled in as morning brightened. People waited in scattered lines. I paced a little, then stopped near the edge. A voice announced a slight delay. The smell of coffee drifted by. I wondered about timing and plans. The doors slid apart and passengers filed on. I joined them after a moment.'), evaluator='Writing Style', score=0.7, reason='the writing styles exhibit a strong similarity across most key dimensions, particularly in tone and rhythm, with both pieces utilizing descriptive language and a reflective tone. However, there are notable divergences in sentence structure and lexical complexity, as the expected output features longer, more complex sentences and a richer vocabulary, while the actual output relies on shorter, simpler sentences and more straightforward language.', confidence=0.3999999999999999, timestamp=datetime.datetime(2025, 10, 16, 13, 14, 30, 629850), details={}),
#  'Range 4-5: Moderately dissimilar to borderline; some alignment but balanced differences.': Result(source=Book(title='Platform Beat', author='Anonymous', text='The train slid into the station at dawn. Glass caught the first pale light. Commuters gathered in small, breath-fogged constellations. I counted the steps: four to the bench, three to the edge, one to the line. The speaker crackled; the schedule shifted by two minutesâ€”no drama, only a tilt. I breathed in metal, brewed coffee, rain-memory. Questions rose, then settled: where, why, when. I did not answer. Instead, I watched the doors part like a slow yawn. People flowed. I waited. Then I stepped in, not first, not last, but exactly on the beat.', language='English'), target=AnonymousText(text='The train reached the station in early light. Passengers gathered in groups. I took four steps to the bench, three to the edge, one to the line. An announcement noted a two-minute delay. The air tasted of coffee and damp rails. Questions came to mind, then passed. When the doors opened, the crowd moved. I entered somewhere in the middle.'), evaluator='Writing Style', score=0.3, reason='the writing styles exhibit clear dissimilarity across multiple dimensions, particularly in assertiveness, lexical complexity, and sentence structure. The analysis shows that the actual output is more straightforward and lacks the complexity and richness found in the expected output, leading to a fundamental difference in style.', confidence=0.4, timestamp=datetime.datetime(2025, 10, 16, 13, 18, 56, 388168), details={}),
#  'Range 6-8: Moderate to very strong similarity; multiple dimensions align with minor divergences.': Result(source=Book(title='Platform Beat', author='Anonymous', text='The train slid into the station at dawn. Glass caught the first pale light. Commuters gathered in small, breath-fogged constellations. I counted the steps: four to the bench, three to the edge, one to the line. The speaker crackled; the schedule shifted by two minutesâ€”no drama, only a tilt. I breathed in metal, brewed coffee, rain-memory. Questions rose, then settled: where, why, when. I did not answer. Instead, I watched the doors part like a slow yawn. People flowed. I waited. Then I stepped in, not first, not last, but exactly on the beat.', language='English'), target=AnonymousText(text='Dawn found the train at the station. The glass held pale light. Commuters formed small knots. I counted: four, three, one. The speaker announced a brief delayâ€”two minutes. I smelled coffee and wet iron. Questions rose and fell. The doors slid open. People streamed in. I followed, neither leading nor trailing, roughly in rhythm.'), evaluator='Writing Style', score=0.8, reason='the writing styles exhibit a high degree of similarity in tone, rhythm, and flow, with only minor differences in lexical complexity and sentence structure. The overall narrative style and organization align closely, suggesting a strong but not identical match, as indicated by the evaluations in the NonBinaryJudgementNode and the final VerdictNode.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 16, 13, 19, 17, 55638), details={}),
#  'Range 9-10: Near-identical to virtually identical; subtle, sparse divergences.': Result(source=Book(title='Platform Beat', author='Anonymous', text='The train slid into the station at dawn. Glass caught the first pale light. Commuters gathered in small, breath-fogged constellations. I counted the steps: four to the bench, three to the edge, one to the line. The speaker crackled; the schedule shifted by two minutesâ€”no drama, only a tilt. I breathed in metal, brewed coffee, rain-memory. Questions rose, then settled: where, why, when. I did not answer. Instead, I watched the doors part like a slow yawn. People flowed. I waited. Then I stepped in, not first, not last, but exactly on the beat.', language='English'), target=AnonymousText(text='The train slid into the platform at dawn. Windows caught the first pale light. Commuters formed breath-fogged clusters. I tallied the steps: four to the bench, three to the edge, one to the line. The speaker hissed; the timetable shifted by two minutesâ€”no drama, only a tilt. I breathed in steel, coffee, rain-memory. Questions lifted, then settled: where, why, when. I withheld answers. The doors opened like a measured yawn. People flowed. I waited. Then I stepped in, not first, not last, exactly on the beat.'), evaluator='Writing Style', score=0.8, reason='the writing styles exhibit a high degree of alignment in terms of tone, rhythm, and flow, with only minor differences in lexical complexity and sentence structure. This conclusion is drawn from the evaluations at various nodes in the DAG traversal, particularly the strong similarities noted in the Sentence Structure Similarity (7/10), Rhythm & Flow Similarity (7/10), and the overall assessment of very strong similarity (8/10) in the final writing style score.', confidence=0.6000000000000001, timestamp=datetime.datetime(2025, 10, 16, 13, 19, 36, 99612), details={})}

# %%
errors
# Out:
# {}
